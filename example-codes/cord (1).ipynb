# %%
# !pip install -U git+https://github.com/dgunning/cord19.git

# %%
# !pip install git+https://github.com/neuml/cord19q

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.2.4/en_core_sci_sm-0.2.4.tar.gz

# %% [markdown]
# # Following the pipeline of
# ### https://www.kaggle.com/dgunning/building-a-cord19-research-engine-with-bm25

# %%
# %load_ext autotime
import os

os.environ["MODIN_ENGINE"] = "ray"  # Modin will use Ray
# os.environ["MODIN_ENGINE"] = "dask
os.environ['MODIN_MEMORY'] ='2000000000000'
import modin.pandas as pd
# Out:
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 1.75 s

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True
# time: 10.1 s

# %%
from cord import ResearchPapers

research_papers = ResearchPapers.load(data_dir='/home/syncthing/others/covid/data/')
# Out:
# Loading metadata from /home/syncthing/others/covid/data/CORD-19-research-challenge
# Cleaning metadata
# Applying tags to metadata
#
# Indexing research papers
# Creating the BM25 index from the abstracts of the papers
# Use index="text" if you want to index the texts of the paper instead
# Finished Indexing in 53.0 seconds
# time: 1min 11s

# %%
research_papers
# Out:
# <h3>CORD 19 Research Papers</h3>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Papers</th>
#       <th>Oldest</th>
#       <th>Newest</th>
#       <th>SARS-COV-2</th>
#       <th>SARS</th>
#       <th>Coronavirus</th>
#       <th>Virus</th>
#       <th>Antivirals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th></th>
#       <td>45774</td>
#       <td>1951-03-27</td>
#       <td>2020-12-31</td>
#       <td>2427</td>
#       <td>3495</td>
#       <td>8832</td>
#       <td>26380</td>
#       <td>374</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <hr/>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>abstract</th>
#       <th>journal</th>
#       <th>authors</th>
#       <th>published</th>
#       <th>when</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>SIANN: Strain Identification by Alignment to N...</td>
#       <td>Next-generation sequencing is increasingly bei...</td>
#       <td></td>
#       <td>Samuel Minot; Stephen D Turner; Krista L Ternu...</td>
#       <td>2014-01-10</td>
#       <td>6 years ago</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Spatial epidemiology of networked metapopulati...</td>
#       <td>An emerging disease is one infectious epidemic...</td>
#       <td></td>
#       <td>Lin WANG; Xiang Li</td>
#       <td>2014-06-04</td>
#       <td>6 years ago</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Sequencing of the human IG light chain loci fr...</td>
#       <td>Germline variation at immunoglobulin gene (IG)...</td>
#       <td></td>
#       <td>Corey T Watson; Karyn Meltz Steinberg; Tina A ...</td>
#       <td>2014-07-03</td>
#       <td>6 years ago</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Bayesian mixture analysis for metagenomic comm...</td>
#       <td>Deep sequencing of clinical samples is now an ...</td>
#       <td></td>
#       <td>Sofia Morfopoulou; Vincent Plagnol</td>
#       <td>2014-07-25</td>
#       <td>6 years ago</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Mapping a viral phylogeny onto outbreak trees ...</td>
#       <td>Developing methods to reconstruct transmission...</td>
#       <td></td>
#       <td>Stephen P Velsko; Jonathan E Allen</td>
#       <td>2014-11-11</td>
#       <td>5 years ago</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>45769</th>
#       <td>Personal Protective Equipment: Protecting Heal...</td>
#       <td>Purpose The recent Ebola epidemic that devast...</td>
#       <td>Clinical Therapeutics</td>
#       <td>Fischer, William A.; Weber, David J.; Wohl, Da...</td>
#       <td>2015-11-01</td>
#       <td>4 years ago</td>
#     </tr>
#     <tr>
#       <th>45770</th>
#       <td>Viruses and asthma</td>
#       <td>Background Viral respiratory infection has lo...</td>
#       <td>Biochimica et Biophysica Acta (BBA) - General ...</td>
#       <td>Dulek, Daniel E.; Peebles, R. Stokes</td>
#       <td>2011-11-30</td>
#       <td>8 years ago</td>
#     </tr>
#     <tr>
#       <th>45771</th>
#       <td>Why the WHO won't use the p-word</td>
#       <td>There are no criteria for a pandemic, but covi...</td>
#       <td>New Scientist</td>
#       <td>MacKenzie, Debora</td>
#       <td>2020-03-07</td>
#       <td>4 weeks ago</td>
#     </tr>
#     <tr>
#       <th>45772</th>
#       <td>Communication, transparency key as Canada face...</td>
#       <td>Communication, transparency key as Canada face...</td>
#       <td>Canadian Medical Association Journal</td>
#       <td>Glauser, Wendy</td>
#       <td>2020-02-17</td>
#       <td>1 month ago</td>
#     </tr>
#     <tr>
#       <th>45773</th>
#       <td>Searching for animal models and potential targ...</td>
#       <td>Emerging and re-emerging pathogens represent a...</td>
#       <td>One Health</td>
#       <td>Vergara-Alert, Júlia; Vidal, Enric; Bensaid, A...</td>
#       <td>2017-03-03</td>
#       <td>3 years ago</td>
#     </tr>
#   </tbody>
# </table>
# <p>45774 rows × 6 columns</p>
# </div>
# <style>
# h3 {color: #4169E1}
# </style>
# time: 158 ms

# %%
research_papers.metadata.head()
# Out:
#    cord_uid                                       sha   source  \
# 0  vho70jcx  f056da9c64fbf00a4645ae326e8a4339d015d155  biorxiv
# 1  i9tbix2v  daf32e013d325a6feb80e83d15aabc64a48fae33  biorxiv
# 2  62gfisc6  f33c6d94b0efaa198f8f3f20e644625fa3fe10d2  biorxiv
# 3  058r9486  4da8a87e614373d56070ed272487451266dce919  biorxiv
# 4  wich35l7  eccef80cfbe078235df22398f195d5db462d8000  biorxiv
#
#                                                title             doi pmcid  \
# 0  SIANN: Strain Identification by Alignment to N...  10.1101/001727   NaN
# 1  Spatial epidemiology of networked metapopulati...  10.1101/003889   NaN
# 2  Sequencing of the human IG light chain loci fr...  10.1101/006866   NaN
# 3  Bayesian mixture analysis for metagenomic comm...  10.1101/007476   NaN
# 4  Mapping a viral phylogeny onto outbreak trees ...  10.1101/010389   NaN
#
#   pubmed_id  license                                           abstract  \
# 0       NaN  biorxiv  Next-generation sequencing is increasingly bei...
# 1       NaN  biorxiv  An emerging disease is one infectious epidemic...
# 2       NaN  biorxiv  Germline variation at immunoglobulin gene (IG)...
# 3       NaN  biorxiv  Deep sequencing of clinical samples is now an ...
# 4       NaN  biorxiv  Developing methods to reconstruct transmission...
#
#    published  ... has_text   full_text_file                             url  \
# 0 2014-01-10  ...     True  biorxiv_medrxiv  https://doi.org/10.1101/001727
# 1 2014-06-04  ...     True  biorxiv_medrxiv  https://doi.org/10.1101/003889
# 2 2014-07-03  ...     True  biorxiv_medrxiv  https://doi.org/10.1101/006866
# 3 2014-07-25  ...     True  biorxiv_medrxiv  https://doi.org/10.1101/007476
# 4 2014-11-11  ...     True  biorxiv_medrxiv  https://doi.org/10.1101/010389
#
#           when  covid_related  virus coronavirus   sars  \
# 0  6 years ago          False  False       False  False
# 1  6 years ago          False  False       False   True
# 2  6 years ago          False  False       False  False
# 3  6 years ago          False   True       False  False
# 4  5 years ago          False   True       False  False
#
#                                         index_tokens  antivirals
# 0  [next-generation, sequencing, increasingly, us...
# 1  [emerging, disease, infectious, epidemic, caus...
# 2  [germline, variation, immunoglobulin, gene, ig...
# 3  [deep, sequencing, clinical, samples, establis...
# 4  [developing, methods, reconstruct, transmissio...
#
# [5 rows x 24 columns]

# %%
import pandas as pd

research_papers.metadata.to_pickle('covid19_kaggle.pkl')
research_papers.metadata.to_csv('covid19_kaggle.csv')

# %%
research_papers.metadata.columns
# Out:
# Index(['cord_uid', 'sha', 'source', 'title', 'doi', 'pmcid', 'pubmed_id',
#        'license', 'abstract', 'published', 'authors', 'journal',
#        'Microsoft Academic Paper ID', 'WHO #Covidence', 'has_text',
#        'full_text_file', 'url', 'when', 'covid_related', 'virus',
#        'coronavirus', 'sars', 'index_tokens', 'antivirals'],
#       dtype='object')
# time: 8.44 ms

# %%
research_papers.metadata['journal'].nunique()
# Out:
# 4886
# time: 15.7 ms

# %%
research_papers.metadata['journal'].unique()
# Out:
# array(['', 'Chin Med J (Engl)', 'J Clin Med', ...,
#        'Medical Image Analysis', 'Pediatric Reports. 2020;12(1)',
#        'Current Opinion in Chemical Engineering'], dtype=object)
# time: 15.4 ms

# %% [markdown]
# # search functionality

# %%
research_papers.searchbar('antiviral treatment')
# Out:
# VBox(children=(HBox(children=(Text(value='antiviral treatment', layout=Layout(width='400px')), Button(button_s…
# Output()
# time: 1.42 s

# %%
research_papers.match('H[0-9]N[0-9]')
# Out:
# <h3>CORD 19 Research Papers</h3>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Papers</th>
#       <th>Oldest</th>
#       <th>Newest</th>
#       <th>SARS-COV-2</th>
#       <th>SARS</th>
#       <th>Coronavirus</th>
#       <th>Virus</th>
#       <th>Antivirals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th></th>
#       <td>19</td>
#       <td>2005-08-19</td>
#       <td>2020-02-04</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>13</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <hr/>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>abstract</th>
#       <th>journal</th>
#       <th>authors</th>
#       <th>published</th>
#       <th>when</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3023</th>
#       <td>Evolutionary and Transmission Dynamics of Reas...</td>
#       <td>H5N1 highly pathogenic avian influenza (HPAI) ...</td>
#       <td>PLoS Pathog</td>
#       <td>Lam, Tommy Tsan-Yuk; Hon, Chung-Chau; Pybus, O...</td>
#       <td>2008-08-22</td>
#       <td>12 years ago</td>
#     </tr>
#     <tr>
#       <th>5721</th>
#       <td>H7N9 avian influenza virus - search and re-search</td>
#       <td>H7N9 avian influenza virus - search and re-search</td>
#       <td>Emerg Microbes Infect</td>
#       <td>Wen, Yu-Mei; Klenk, Hans-Dieter</td>
#       <td>2013-04-10</td>
#       <td>7 years ago</td>
#     </tr>
#     <tr>
#       <th>6221</th>
#       <td>H1N1 influenza pandemic: What we did and what ...</td>
#       <td>H1N1 influenza pandemic: What we did and what ...</td>
#       <td>Indian J Crit Care Med</td>
#       <td>Jog, Sameer; Kadam, Deelip</td>
#       <td>2013-01-01</td>
#       <td>7 years ago</td>
#     </tr>
#     <tr>
#       <th>9540</th>
#       <td>Two Genetically Similar H9N2 Influenza A Virus...</td>
#       <td>H9N2 Avian influenza virus has repeatedly infe...</td>
#       <td>Front Microbiol</td>
#       <td>Liu, Qingtao; Liu, Yuzhuo; Yang, Jing; Huang, ...</td>
#       <td>2016-11-04</td>
#       <td>3 years ago</td>
#     </tr>
#     <tr>
#       <th>9613</th>
#       <td>Sensitization with vaccinia virus encoding H5N...</td>
#       <td>H5N1 highly pathogenic avian influenza (H5N1 H...</td>
#       <td>Sci Rep</td>
#       <td>Yasui, Fumihiko; Itoh, Yasushi; Ikejiri, Ai; K...</td>
#       <td>2016-11-28</td>
#       <td>3 years ago</td>
#     </tr>
#     <tr>
#       <th>10490</th>
#       <td>Replication of H9 influenza viruses in the hum...</td>
#       <td>H9N2 viruses are the most widespread influenza...</td>
#       <td>Sci Rep</td>
#       <td>Chan, Renee W. Y.; Chan, Louisa L. Y.; Mok, Ch...</td>
#       <td>2017-07-24</td>
#       <td>3 years ago</td>
#     </tr>
#     <tr>
#       <th>10625</th>
#       <td>Characterization of Monoclonal Antibodies agai...</td>
#       <td>H1N1 swine influenza viruses (SIV) are prevale...</td>
#       <td>Viruses</td>
#       <td>Liu, Yun; Li, Hongtao; Xue, Yujia; Zhao, Shuan...</td>
#       <td>2017-08-08</td>
#       <td>3 years ago</td>
#     </tr>
#     <tr>
#       <th>12442</th>
#       <td>Broad neutralizing activity of a human monoclo...</td>
#       <td>H7N9 influenza virus has been circulating amon...</td>
#       <td>Emerg Microbes Infect</td>
#       <td>Chen, Cong; Liu, Zuliang; Liu, Liguo; Xiao, Ya...</td>
#       <td>2018-11-14</td>
#       <td>1 year ago</td>
#     </tr>
#     <tr>
#       <th>14550</th>
#       <td>Detection methods for influenza A H1N1 virus w...</td>
#       <td>H1N1 (Swine flu) is caused by influenza A viru...</td>
#       <td>Biosci Rep</td>
#       <td>Ravina,; Dalal, Anita; Mohan, Hari; Prasad, Mi...</td>
#       <td>2020-02-04</td>
#       <td>2 months ago</td>
#     </tr>
#     <tr>
#       <th>15810</th>
#       <td>Full-length characterization and phylogenetic ...</td>
#       <td>H9N2 avian influenza A viruses (AIV) have beco...</td>
#       <td>Comp Clin Path</td>
#       <td>Ghalyanchi Langeroudi, Arash; Karimi, Vahid; T...</td>
#       <td>2012-01-21</td>
#       <td>8 years ago</td>
#     </tr>
#     <tr>
#       <th>16246</th>
#       <td>Avian Influenza: Recent Epidemiology, Travel-R...</td>
#       <td>H5N1 influenza continues to smolder in Southea...</td>
#       <td>Curr Infect Dis Rep</td>
#       <td>Lazarus, Rajeka; Lim, Poh Lian</td>
#       <td>2014-12-05</td>
#       <td>5 years ago</td>
#     </tr>
#     <tr>
#       <th>17277</th>
#       <td>Dynamic variations of the peripheral blood imm...</td>
#       <td>H7N9 influenza is a recently emerging infectio...</td>
#       <td>Experimental and Therapeutic Medicine</td>
#       <td>Chen, Cheng; Sun, Wei; Chen, Jun; Huang, Jian-An</td>
#       <td>2017-02-21</td>
#       <td>3 years ago</td>
#     </tr>
#     <tr>
#       <th>20518</th>
#       <td>Characterization of Two Human Monoclonal Antib...</td>
#       <td>H7N9 was a cause of significant global health ...</td>
#       <td>Journal of Virology</td>
#       <td>Wang, Jianmin; Chen, Zhe; Bao, Linlin; Zhang, ...</td>
#       <td>2015-06-10</td>
#       <td>5 years ago</td>
#     </tr>
#     <tr>
#       <th>21504</th>
#       <td>Structures of complexes formed by H5 influenza...</td>
#       <td>H5N1 avian influenza viruses remain a threat t...</td>
#       <td>Proceedings of the National Academy of Sciences</td>
#       <td>Xiong, Xiaoli; Corti, Davide; Liu, Junfeng; Pi...</td>
#       <td>2015-07-13</td>
#       <td>5 years ago</td>
#     </tr>
#     <tr>
#       <th>24105</th>
#       <td>H5N1 influenza and the implications for Europe...</td>
#       <td>H5N1 influenza and the implications for Europe...</td>
#       <td></td>
#       <td>Coulombier, Denis; Ekdahl, Karl</td>
#       <td>2005-08-20</td>
#       <td>15 years ago</td>
#     </tr>
#     <tr>
#       <th>33024</th>
#       <td>H5N1 influenza pandemic: contingency plans</td>
#       <td>H5N1 influenza pandemic: contingency plans</td>
#       <td>The Lancet</td>
#       <td>Tsang, Kenneth WT; Eng, Philip; Liam, CK; Shim...</td>
#       <td>2005-08-19</td>
#       <td>15 years ago</td>
#     </tr>
#     <tr>
#       <th>33097</th>
#       <td>H1N1, public health security, bioethics, and h...</td>
#       <td>H1N1, public health security, bioethics, and h...</td>
#       <td>The Lancet</td>
#       <td>Tarantola, D; Amon, J; Zwi, A; Gruskin, S; Gos...</td>
#       <td>2009-06-26</td>
#       <td>11 years ago</td>
#     </tr>
#     <tr>
#       <th>43727</th>
#       <td>Pathology, Molecular Biology, and Pathogenesis...</td>
#       <td>H5N1 avian influenza is a highly fatal infecti...</td>
#       <td>The American Journal of Pathology</td>
#       <td>Korteweg, Christine; Gu, Jiang</td>
#       <td>2008-05-31</td>
#       <td>12 years ago</td>
#     </tr>
#     <tr>
#       <th>45323</th>
#       <td>H7N9 influenza-the laboratory presentations: A...</td>
#       <td>H7N9 influenza-the laboratory presentations: A...</td>
#       <td>Asian Pacific Journal of Tropical Biomedicine</td>
#       <td>Wiwanitkit, Viroj</td>
#       <td>2013-07-31</td>
#       <td>7 years ago</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <style>
# h3 {color: #4169E1}
# </style>
# time: 153 ms

# %% [markdown]
# # For task 4
#
# ## item 1: Effectiveness of drugs being developed and tried to treat COVID-19 patients.
# ### Clinical and bench trials to investigate less common viral inhibitors against COVID-19 such as naproxen, clarithromycin, and minocyclinethat that may exert effects on viral replication.

# %%
inhibitor = research_papers.contains('inhibitors', column='abstract').since_sarscov2()
inhibitor
# Out:
# <h3>CORD 19 Research Papers</h3>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Papers</th>
#       <th>Oldest</th>
#       <th>Newest</th>
#       <th>SARS-COV-2</th>
#       <th>SARS</th>
#       <th>Coronavirus</th>
#       <th>Virus</th>
#       <th>Antivirals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th></th>
#       <td>62</td>
#       <td>2019-12-06</td>
#       <td>2020-12-31</td>
#       <td>32</td>
#       <td>1</td>
#       <td>38</td>
#       <td>51</td>
#       <td>14</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <hr/>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>abstract</th>
#       <th>journal</th>
#       <th>authors</th>
#       <th>published</th>
#       <th>when</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>81</th>
#       <td>Translational profiling of macrophages infecte...</td>
#       <td>The protozoan parasite Leishmania donovani (L....</td>
#       <td></td>
#       <td>Visnu Chaparro; Louis-Philippe Leroux; Laia Ma...</td>
#       <td>2019-12-20</td>
#       <td>3 months ago</td>
#     </tr>
#     <tr>
#       <th>91</th>
#       <td>Hotspots of aberrant enhancer activity in fibr...</td>
#       <td>Fibrolamellar carcinoma (FLC) is a rare, thera...</td>
#       <td></td>
#       <td>Timothy A. Dinh; Ramja Sritharan; F. Donelson ...</td>
#       <td>2020-01-18</td>
#       <td>2 months ago</td>
#     </tr>
#     <tr>
#       <th>122</th>
#       <td>Therapeutic Drugs Targeting 2019-nCoV Main Pro...</td>
#       <td>2019 Novel Coronavirus (2019-nCoV) is a virus ...</td>
#       <td></td>
#       <td>Yan Li; Jinyong Zhang; Ning Wang; Haibo Li; Yu...</td>
#       <td>2020-01-29</td>
#       <td>2 months ago</td>
#     </tr>
#     <tr>
#       <th>126</th>
#       <td>Potential inhibitors for 2019-nCoV coronavirus...</td>
#       <td>Starting from December 2019, a novel coronavir...</td>
#       <td></td>
#       <td>Xin Liu; Xiu-Jie Wang</td>
#       <td>2020-01-29</td>
#       <td>2 months ago</td>
#     </tr>
#     <tr>
#       <th>136</th>
#       <td>Nucleotide Analogues as Inhibitors of Viral Po...</td>
#       <td>Coronaviruses such as the newly discovered vir...</td>
#       <td></td>
#       <td>Jingyue Ju; Shiv Kumar; Xiaoxu Li; Steffen Joc...</td>
#       <td>2020-01-31</td>
#       <td>2 months ago</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>43560</th>
#       <td>Structure, Function, and Antigenicity of the S...</td>
#       <td>The emergence of SARS-CoV-2 has resulted in &gt;...</td>
#       <td>Cell</td>
#       <td>Walls, Alexandra C.; Park, Young-Jun; Tortoric...</td>
#       <td>2020-03-09</td>
#       <td>3 weeks ago</td>
#     </tr>
#     <tr>
#       <th>43853</th>
#       <td>Potential inhibitors against 2019-nCoV coronav...</td>
#       <td>Potential inhibitors against 2019-nCoV coronav...</td>
#       <td>Journal of Genetics and Genomics</td>
#       <td>Liu, Xin; Wang, Xiu-Jie</td>
#       <td>2020-02-13</td>
#       <td>1 month ago</td>
#     </tr>
#     <tr>
#       <th>44257</th>
#       <td>Are patients with hypertension and diabetes me...</td>
#       <td>The most distinctive comorbidities of 32 non-s...</td>
#       <td>The Lancet Respiratory Medicine</td>
#       <td>Fang, Lei; Karakiulakis, George; Roth, Michael</td>
#       <td>2020-03-11</td>
#       <td>3 weeks ago</td>
#     </tr>
#     <tr>
#       <th>44528</th>
#       <td>Structure analysis of the receptor binding of ...</td>
#       <td>2019-nCoV is a newly identified coronavirus wi...</td>
#       <td>Biochemical and Biophysical Research Communica...</td>
#       <td>Chen, Yun; Guo, Yao; Pan, Yihang; Zhao, Zhizhu...</td>
#       <td>2020-01-01</td>
#       <td>3 months ago</td>
#     </tr>
#     <tr>
#       <th>45242</th>
#       <td>Comparison of broad-spectrum antiviral activit...</td>
#       <td>Rocaglates, a class of natural compounds isol...</td>
#       <td>Antiviral Research</td>
#       <td>Müller, Christin; Obermann, Wiebke; Schulte, F...</td>
#       <td>2020-03-31</td>
#       <td>2 days ago</td>
#     </tr>
#   </tbody>
# </table>
# <p>62 rows × 6 columns</p>
# </div>
# <style>
# h3 {color: #4169E1}
# </style>
# time: 523 ms

# %%
naproxen = research_papers.contains('naproxen',column='abstract')
naproxen
# Out:
# <h3>CORD 19 Research Papers</h3>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Papers</th>
#       <th>Oldest</th>
#       <th>Newest</th>
#       <th>SARS-COV-2</th>
#       <th>SARS</th>
#       <th>Coronavirus</th>
#       <th>Virus</th>
#       <th>Antivirals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th></th>
#       <td>3</td>
#       <td>1984-06-30</td>
#       <td>2018-08-01</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <hr/>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>abstract</th>
#       <th>journal</th>
#       <th>authors</th>
#       <th>published</th>
#       <th>when</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18273</th>
#       <td>Nonsteroidal Anti-inflammatory Drugs Potently ...</td>
#       <td>Zika virus (ZIKV) is genetically and biologica...</td>
#       <td>Journal of Virology</td>
#       <td>Pan, Ting; Peng, Zhilin; Tan, Likai; Zou, Fan;...</td>
#       <td>2018-08-01</td>
#       <td>2 years ago</td>
#     </tr>
#     <tr>
#       <th>26887</th>
#       <td>Reversible restriction of vesicular stomatitis...</td>
#       <td>Indomethacin, a potent nonsteroidal inhibitor...</td>
#       <td>Virology</td>
#       <td>Mukherjee, Pranab K.; Simpson, Robert W.</td>
#       <td>1984-06-30</td>
#       <td>36 years ago</td>
#     </tr>
#     <tr>
#       <th>45484</th>
#       <td>The role of adjuvant immunomodulatory agents f...</td>
#       <td>A severe inflammatory immune response with hy...</td>
#       <td>Antiviral Research</td>
#       <td>Hui, David S.; Lee, Nelson; Chan, Paul K.; Bei...</td>
#       <td>2018-02-28</td>
#       <td>2 years ago</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <style>
# h3 {color: #4169E1}
# </style>
# time: 305 ms

# %%
clarithromycin = research_papers.contains('clarithromycin', column='abstract')
clarithromycin
# Out:
# <h3>CORD 19 Research Papers</h3>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Papers</th>
#       <th>Oldest</th>
#       <th>Newest</th>
#       <th>SARS-COV-2</th>
#       <th>SARS</th>
#       <th>Coronavirus</th>
#       <th>Virus</th>
#       <th>Antivirals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th></th>
#       <td>8</td>
#       <td>2001-07-31</td>
#       <td>2018-02-28</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>6</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <hr/>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>abstract</th>
#       <th>journal</th>
#       <th>authors</th>
#       <th>published</th>
#       <th>when</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7879</th>
#       <td>A case of bronchiolitis obliterans organizing ...</td>
#       <td>: Bronchiolitis obliterans organizing pneumoni...</td>
#       <td>BMC Infect Dis</td>
#       <td>Jung, In Young; Jeon, Yong Duk; Ahn, Mi-young;...</td>
#       <td>2015-07-23</td>
#       <td>5 years ago</td>
#     </tr>
#     <tr>
#       <th>25240</th>
#       <td>Aerobic Bacteriological Study of Acute Exacerb...</td>
#       <td>: The natural history of chronic obstructive p...</td>
#       <td>JOURNAL OF CLINICAL AND DIAGNOSTIC RESEARCH</td>
#       <td>Sharan, Hariom</td>
#       <td>2015-01-01</td>
#       <td>5 years ago</td>
#     </tr>
#     <tr>
#       <th>35255</th>
#       <td></td>
#       <td>Treatment guidelines developed by the Sinus a...</td>
#       <td>Otolaryngology - Head and Neck Surgery</td>
#       <td></td>
#       <td>2004-01-31</td>
#       <td>16 years ago</td>
#     </tr>
#     <tr>
#       <th>35949</th>
#       <td>Diagnóstico rápido de las infecciones del trac...</td>
#       <td>Resumen Las técnicas de diagnóstico rápido son...</td>
#       <td>Enfermedades Infecciosas y Microbiología Clínica</td>
#       <td>Balsalobre-Arenas, Luz; Alarcón-Cavero, Teresa</td>
#       <td>2017-07-31</td>
#       <td>3 years ago</td>
#     </tr>
#     <tr>
#       <th>38289</th>
#       <td>Acute Disseminated Encephalomyelitis in Childr...</td>
#       <td>Background Acute disseminated encephalomyelit...</td>
#       <td>Pediatric Neurology</td>
#       <td>Erol, Ilknur; Özkale, Yasemin; Alkan, Özlem; A...</td>
#       <td>2013-10-31</td>
#       <td>6 years ago</td>
#     </tr>
#     <tr>
#       <th>38552</th>
#       <td>Bacteriological and clinical efficacy of vario...</td>
#       <td>A total of 123 community paediatricians and 2...</td>
#       <td>International Journal of Antimicrobial Agents</td>
#       <td>Rondini, G; Cocuzza, C.E; Cianflone, M; Lanzaf...</td>
#       <td>2001-07-31</td>
#       <td>19 years ago</td>
#     </tr>
#     <tr>
#       <th>39694</th>
#       <td>Crazy-paving sign in high-resolution computed ...</td>
#       <td>The crazy-paving sign is the appearance of a ...</td>
#       <td>Radiography</td>
#       <td>Matsuno, Osamu; Hayama, Yoshitomo; Honda, Hide...</td>
#       <td>2010-05-31</td>
#       <td>10 years ago</td>
#     </tr>
#     <tr>
#       <th>45484</th>
#       <td>The role of adjuvant immunomodulatory agents f...</td>
#       <td>A severe inflammatory immune response with hy...</td>
#       <td>Antiviral Research</td>
#       <td>Hui, David S.; Lee, Nelson; Chan, Paul K.; Bei...</td>
#       <td>2018-02-28</td>
#       <td>2 years ago</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <style>
# h3 {color: #4169E1}
# </style>
# time: 281 ms

# %%
minocyclinethat = research_papers.search('minocyclinethat')
minocyclinethat
# Out:
# <style>
# .authors, .published{
#     padding: 12px 10px 0px 0px;
#     margin: 12px 0px 5px;
# }
# .authors { color: #778899;}
# .published {color: #2F4F4F; font-weight: bold; font-size: 0.9em;}
# h2.cord, h3.cord, h4.cord {margin-top: 15px}
# div.abstract {max-height : 80px; margin-top: 10px}
# .link-text {color: #808080; font-size: 0.9em}
# </style>
# time: 221 ms
